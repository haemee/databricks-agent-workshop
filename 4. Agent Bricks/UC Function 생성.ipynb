# %%
# %sql
CREATE OR REPLACE FUNCTION sudong.agent_bricks.review_response_generator(text STRING)
RETURNS STRING
COMMENT '고객 리뷰에 대한 응답을 생성합니다.'
RETURN ai_query(
  't2t-7a93b705-endpoint',
  text
);

-- 사용 예시
SELECT sudong.agent_bricks.review_response_generator('디자인이 좋고 고급스러워 보입니다');
